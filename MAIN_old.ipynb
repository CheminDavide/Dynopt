# %% [markdown]
# # Dynamic optimization

# %% [markdown]
# ## Intro

# %% [markdown]
# ![title](res/FLOWCHART_videodynopt_v0.1.png)

# %% [markdown]
# ## Init

# %%
# imports
import os #to access system folders
import subprocess #to access ffmpeg in the system
import shutil #to remove directories
import numpy as np #easy vector operations
import math #for operation with infinite
from scipy.optimize import curve_fit #fittin of the curve
import json #to handle json files
import matplotlib.pyplot as pl #to display plots
import tkinter as tk #to import file
from tkinter import filedialog #to open import dialog

#constants
PARAM_AVC = {"crfs": 52, "starting_range": [17,28], "lib": "libx264", "container": "mp4", "add_param": ""}
PARAM_HEVC = {"crfs": 52, "starting_range": [22,33], "lib": "libx265", "container": "mp4", "add_param": ""}
PARAM_VP9 = {"crfs": 64, "starting_range": [15,35], "lib": "libvpx-vp9", "container": "webm", "add_param": "-b:v 0"}

#variables - CUSTOM
codec = "avc" #values: "avc", "hevc", "vp9", !!not implemented: "av1", "vvc"
raw_width = 1920
raw_height = 1080
raw_fps = 29.97
#values "bitrate","vmaf", "psnr" !!not implemented: "ssim", "mssim"
target_list = {"vmaf": [90], "bitrate": []}

#input file
root = tk.Tk()
root.withdraw()
source_path = os.path.relpath(filedialog.askopenfilename())
source_name = os.path.basename(source_path).split('.')[0]
REF_PATH = "test_vids/tempRAW_refs/" #raw files for each shot
[os.remove(REF_PATH+f) for f in os.listdir(REF_PATH)] #clean temp_refs folder
DIST_PATH = "test_vids/temp_encoded/" #encoded files for each shot
[shutil.rmtree(DIST_PATH+f) for f in os.listdir(DIST_PATH)] #clean temp_encoded folder

#assessment files path
tm_file = "rd_results/template.json"
rd_file = "rd_results/" + source_name + ".json"
if not os.path.isfile(rd_file): #if file does not exists create it
    with open(rd_file, 'w') as f:
        pass
VMAF_LOGS = "rd_results/vmaf_logs"

#shot detection
TIME_LOGS = "shot_detection.log"
shot_th = 0.25 #change shot threshold
num_scenes = 0

#output file
OUT_LIST = "shot_list.txt"
OUT_PATH = "test_vids/OPT_vids/"

current_point = None #the current optimum point
new_point = 0 #new value to compare with current_point
#all computed points, by row: crf, bitrate, vmaf, psnr
res_matrix = {"crf": None, "bitrate": None, "vmaf": None, "psnr": None} 

print("init done")
# Out:
# init done

# %% [markdown]
# ## Shot change detection

# %%
#an empty json structure is generated to be filled and to store computed values
def init_res_matrix(x):
    res_matrix["crf"] = np.arange(0,x,1).tolist()
    inf_matrix = np.zeros(x) #infinity to avoid considering zero as a point
    inf_matrix[inf_matrix == 0] = math.inf
    res_matrix["bitrate"] = inf_matrix.tolist()
    res_matrix["vmaf"] = inf_matrix.tolist()
    res_matrix["psnr"] = inf_matrix.tolist()
    
#detect shot changes in the scene and split it into shots
def shot_change_detection(p):
    start_t = 0.0
    end_t = 0.0
    #return when the shot changes
    det = f"ffmpeg -i {p} -filter_complex:v \"select='gt(scene,{shot_th})', \
        metadata=print:file={TIME_LOGS}\" -f null -"
    subprocess.call(det, shell=True)
    #get the total duration for the last cut
    idu = f"ffprobe -v error -select_streams v:0 -show_entries format:stream -print_format json {p}"
    dta = json.loads(subprocess.run(idu.split(), stdout=subprocess.PIPE, stderr=subprocess.STDOUT).stdout)
    duration = dta['format']['duration']
    
    with open("shot_detection.log", 'r') as r:
        tm_log = r.read().splitlines()[::2]
    tm_log.append("end pts_time:" + str(duration))
    n = len(tm_log)
    for i,l in enumerate(tm_log): #for each cut
        #create a folder for each scene
        new_dir = str(i)
        new_path = os.path.join(DIST_PATH, new_dir)
        os.mkdir(new_path)
        
        #cut the video
        end_t = l.split("pts_time:",1)[1]
        cut = f"ffmpeg -ss {start_t} -to {end_t} -i {p} \
            -pix_fmt yuv420p {REF_PATH}scene{str(i).zfill(7)}.yuv"
        subprocess.call(cut, shell=True)
        start_t = end_t
    return n

# %%
struct_points = [] #structure of target points for the json file
struct_shots = [] #structure of shots for the json file

if source_path.endswith(".yuv"):
    print("yuv input")
elif source_path.endswith(".y4m"):
    print("y4m input")
else:
    print("No such an input type")
    exit()

num_scenes = shot_change_detection(source_path)
    
#init values based on the selected output codec
if codec == "avc":
    s_cod = PARAM_AVC
    init_res_matrix(PARAM_AVC["crfs"])
elif codec == "hevc":
    s_cod = PARAM_HEVC
    init_res_matrix(PARAM_HEVC["crfs"])
elif codec == "vp9":
    s_cod = PARAM_VP9
    init_res_matrix(PARAM_VP9["crfs"])
else:
    print("No such an codec")
    exit()

min_range_crf = s_cod["starting_range"][0]
max_range_crf = s_cod["starting_range"][1]

with open(tm_file, 'r') as f:
    o_data = json.load(f)
    
    #add source name and results matrix
    o_data["content"] = source_name
    o_data["versions"][0]["codec"] = codec
    o_data["versions"][0]["width"] = raw_width
    o_data["versions"][0]["height"] = raw_height
    o_data["versions"][0]["fps"] = raw_fps
    o_data["versions"][0]["shots"][0]["assessment"] = res_matrix
    
    #add emplty target points
    base_point = o_data["versions"][0]["shots"][0]["opt_points"][0]
    for t_name in target_list:
        for t_val in target_list[t_name]:
            base_point["metric"] = t_name
            base_point["target"] = t_val
            struct_points.append(base_point.copy())
    o_data["versions"][0]["shots"][0]["opt_points"] = struct_points
    
    #add empty shots
    base_shot = o_data["versions"][0]["shots"][0]
    for i in range(0, num_scenes):
        base_shot["index"] = i #assign index to shots in json file
        struct_shots.append(base_shot.copy())
    o_data["versions"][0]["shots"] = struct_shots

with open(rd_file, 'w') as w:
    json.dump(o_data, w, separators=(',',': '))
# Out:
# y4m input
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# Input #0, yuv4mpegpipe, from 'test_vids/srcRAW_FullHD/rush_field_cuts_1080p.y4m':
#   Duration: 00:00:19.02, start: 0.000000, bitrate: 994335 kb/s
#   Stream #0:0: Video: rawvideo (Y42B / 0x42323459), yuv422p(progressive), 1920x1080, SAR 1:1 DAR 16:9, 29.97 fps, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 (rawvideo) -> select:default
#   metadata:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv422p(progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=    3 fps=0.0 q=-0.0 Lsize=N/A time=00:00:16.04 bitrate=N/A speed=25.7x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# Input #0, yuv4mpegpipe, from 'test_vids/srcRAW_FullHD/rush_field_cuts_1080p.y4m':
#   Duration: 00:00:19.02, start: 0.000000, bitrate: 994335 kb/s
#   Stream #0:0: Video: rawvideo (Y42B / 0x42323459), yuv422p(progressive), 1920x1080, SAR 1:1 DAR 16:9, 29.97 fps, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p(tv, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 745750 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 rawvideo
# frame=  318 fps=0.0 q=-0.0 Lsize=  965925kB time=00:00:10.61 bitrate=745750.2kbits/s speed=10.7x
# video:965925kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# Input #0, yuv4mpegpipe, from 'test_vids/srcRAW_FullHD/rush_field_cuts_1080p.y4m':
#   Duration: 00:00:19.02, start: 0.000000, bitrate: 994335 kb/s
#   Stream #0:0: Video: rawvideo (Y42B / 0x42323459), yuv422p(progressive), 1920x1080, SAR 1:1 DAR 16:9, 29.97 fps, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'test_vids/tempRAW_refs/scene0000001.yuv':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p(tv, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 745750 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 rawvideo
# frame=   60 fps=0.0 q=-0.0 Lsize=  182250kB time=00:00:02.00 bitrate=745750.2kbits/s speed=10.7x
# video:182250kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# Input #0, yuv4mpegpipe, from 'test_vids/srcRAW_FullHD/rush_field_cuts_1080p.y4m':
#   Duration: 00:00:19.02, start: 0.000000, bitrate: 994335 kb/s
#   Stream #0:0: Video: rawvideo (Y42B / 0x42323459), yuv422p(progressive), 1920x1080, SAR 1:1 DAR 16:9, 29.97 fps, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'test_vids/tempRAW_refs/scene0000002.yuv':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p(tv, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 745750 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 rawvideo
# frame=  102 fps=0.0 q=-0.0 Lsize=  309825kB time=00:00:03.40 bitrate=745750.2kbits/s speed=10.5x
# video:309825kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# Input #0, yuv4mpegpipe, from 'test_vids/srcRAW_FullHD/rush_field_cuts_1080p.y4m':
#   Duration: 00:00:19.02, start: 0.000000, bitrate: 994335 kb/s
#   Stream #0:0: Video: rawvideo (Y42B / 0x42323459), yuv422p(progressive), 1920x1080, SAR 1:1 DAR 16:9, 29.97 fps, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'test_vids/tempRAW_refs/scene0000003.yuv':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p(tv, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 745750 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 rawvideo
# frame=   90 fps=0.0 q=-0.0 Lsize=  273375kB time=00:00:03.00 bitrate=745750.2kbits/s speed=10.5x
# video:273375kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %% [markdown]
# ## Optimization
# Find the shot encoded to a certain crf that has the closest quality or rate to the target

# %%
def encode(s,i,p):
    add_info = s_cod["add_param"]
    lib = s_cod["lib"]
    o = DIST_PATH + str(i) + "/" + str(p) + "_" + codec.upper() + "." + s_cod["container"]
    enc = f"ffmpeg -f rawvideo -video_size {raw_width}x{raw_height} -r {raw_fps} \
        -pixel_format yuv420p -i {REF_PATH+s} -c:v {lib} -crf {new_point} {add_info} {o}"
    subprocess.call(enc, shell=True)
    return o

def assess(s,o):
    c_vmaf = f"ffmpeg -f rawvideo -r {raw_fps} -video_size {raw_width}x{raw_height} -i {REF_PATH+s} \
            -i {o} \
            -lavfi \"[0:v]setpts=PTS-STARTPTS[ref];\
                    [1:v]scale={raw_width}x{raw_height}:flags=bicubic, setpts=PTS-STARTPTS[dist];\
                    [dist][ref]libvmaf=feature=name=psnr:log_path={VMAF_LOGS}:log_fmt=json\" \
            -f null -" #|name=float_ssim|name=float_ms_ssim to compute the other metrics
    subprocess.call(c_vmaf, shell=True)

#store the quality and rate results for each shot at each encoded crf
def save_results(i, c, o):
    with open(VMAF_LOGS, 'r') as r: #extract quality and rate values
        i_data = json.load(r)
        vmaf = i_data["pooled_metrics"]["vmaf"]["mean"]
        psnr = (6*i_data["pooled_metrics"]["psnr_y"]["mean"] + \
            i_data["pooled_metrics"]["psnr_cb"]["mean"] + i_data["pooled_metrics"]["psnr_cr"]["mean"])/8
        info = f"ffprobe -v error -select_streams v:0 -show_entries format:stream -print_format json {o}"
        cout = json.loads(subprocess.run(info.split(), stdout=subprocess.PIPE, stderr=subprocess.STDOUT).stdout)
        bitrate = int(cout['format']['bit_rate'])
        
    with open(rd_file, 'r') as f: #add new values
        o_data = json.load(f)
        o_data["versions"][0]["shots"][i]["assessment"]["crf"][c] = c
        o_data["versions"][0]["shots"][i]["assessment"]["bitrate"][c] = bitrate
        o_data["versions"][0]["shots"][i]["assessment"]["vmaf"][c] = vmaf
        o_data["versions"][0]["shots"][i]["assessment"]["psnr"][c] = psnr
    with open(rd_file, 'w') as w:
        json.dump(o_data, w, separators=(',',': '))
    return o_data["versions"][0]["shots"][i]["assessment"]

def search_opt(t_name, t_val, sx_end, dx_end, i_sx_end, i_dx_end):
    if t_val < sx_end and t_val > dx_end: #if the target is in the range
        n = interpolate(i_sx_end, i_dx_end)
    elif t_val > sx_end: #if the target is out of the range in the left side
        n = 0 #if no other points in this direction had been stored encode at the min crf
        i = i_sx_end - 1
        while n == 0 and i>= 0:
        #the first point you find is the new lower end of the range
            if not res_matrix[t_name][i] == math.inf:
                n = interpolate(i, i_sx_end)
            i -= 1
    elif t_val < dx_end: #if the target is out of the range in the right side
        n = s_cod["crfs"]-1 #if there's no other points, encode at the max crf
        i = i_dx_end + 1
        while n == s_cod["crfs"]-1 and i <= s_cod["crfs"]-1:
            #the first point you find is the new upper end of the range
            if not res_matrix[t_name][i] == math.inf:
                n = interpolate(i_dx_end, i)
            i += 1
    return n

def save_opt(i, t, opt):
    with open(rd_file, 'r') as f:
        o_data = json.load(f)
    o_data["versions"][0]["shots"][i]["opt_points"][t]["crf"] = int(opt)
    with open(rd_file, 'w') as w:
        json.dump(o_data, w, separators=(',',': '))

#linear interpolation of the target and the weight alpha between sx and dx
def interpolate(sx, dx):
    alpha = (res_matrix[t_name][sx] - t_val) / (res_matrix[t_name][sx] - res_matrix[t_name][dx])
    new_point = round(res_matrix["crf"][sx] - alpha * (res_matrix["crf"][sx] - res_matrix["crf"][dx]))
    return new_point

# %%
shot_index = 0
point_index = 0
target_index = 0

for shot in sorted(os.listdir(REF_PATH)): #for each shot
    print("init computing -scene" + str(shot_index))
    for t_name in target_list:
        for t_val in target_list[t_name]:
            while not current_point == new_point: #if no convergence
                if not point_index == 0 : # same shot but new target: new_crf before encoding
                    out = encode(shot, shot_index, new_point) #encoding
                    assess(shot, out) #quality assessment
                    #TODO: results must be weighted based on duration (?)
                    res_matrix = save_results(shot_index, new_point, out)
                    
                if point_index == 0: #if there are no points (first loop)
                    new_point = max_range_crf #encode at the upper value in the starting range
                elif point_index == 1: #if there are no points to compare (second loop)
                    current_point = max_range_crf #the current optimal point is the first one
                    new_point = min_range_crf #in the next loop encode at the lower end of the starting range
                else:
                    #element-wise difference between the metric and its target value
                    difference = np.asarray(abs(np.asarray(res_matrix[t_name]) - t_val))
                    #the minimum difference = the element with the index closer to the target
                    i_first_min = np.argmin(difference)
                    nd_diff = difference.copy()
                    nd_diff[i_first_min] = np.inf #replace the minimum with inf
                    i_second_min = np.argmin(nd_diff) #find the second minimum
                    current_point = i_first_min #the index of the point closer to the target

                    if res_matrix[t_name][i_first_min] == res_matrix[t_name][i_second_min]:
                        #it may happen that the results are the same ex. black short shots
                        current_point = max(i_first_min,i_second_min)
                        new_point = current_point
                    else: #swap the values of the two ends if the lower end is bigger than the upper end
                        if res_matrix[t_name][i_first_min] > res_matrix[t_name][i_second_min]:
                            new_point = search_opt(t_name, t_val, res_matrix[t_name][i_first_min], \
                                        res_matrix[t_name][i_second_min], i_first_min, i_second_min)
                        elif res_matrix[t_name][i_first_min] < res_matrix[t_name][i_second_min]:
                            new_point = search_opt(t_name, t_val, res_matrix[t_name][i_second_min], \
                                        res_matrix[t_name][i_first_min], i_second_min, i_first_min)
                point_index += 1
            save_opt(shot_index, target_index, current_point)
            target_index += 1
            current_point = None
            new_point = 0
    shot_index += 1
    point_index = 0
    target_index = 0
# Out:
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x5641f4f9d4c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5641f4faa180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5641f4faa180] profile High, level 4.0
# [libx264 @ 0x5641f4faa180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=28.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/0/28_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# init computing -scene0
# frame=  318 fps= 22 q=-1.0 Lsize=    7982kB time=00:00:10.51 bitrate=6221.0kbits/s speed=0.742x
# video:7977kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.058664%
# [libx264 @ 0x5641f4faa180] frame I:2     Avg QP:29.81  size:159704
# [libx264 @ 0x5641f4faa180] frame P:79    Avg QP:31.53  size: 58639
# [libx264 @ 0x5641f4faa180] frame B:237   Avg QP:35.06  size: 13569
# [libx264 @ 0x5641f4faa180] consecutive B-frames:  0.6%  0.0%  0.0% 99.4%
# [libx264 @ 0x5641f4faa180] mb I  I16..4:  3.1% 81.2% 15.7%
# [libx264 @ 0x5641f4faa180] mb P  I16..4:  0.4% 11.4%  1.1%  P16..4: 32.8% 20.4% 12.5%  0.0%  0.0%    skip:21.4%
# [libx264 @ 0x5641f4faa180] mb B  I16..4:  0.0%  0.6%  0.0%  B16..8: 33.3%  8.1%  1.7%  direct: 2.7%  skip:53.5%  L0:36.1% L1:51.3% BI:12.6%
# [libx264 @ 0x5641f4faa180] 8x8 transform intra:87.8% inter:71.1%
# [libx264 @ 0x5641f4faa180] coded y,uvDC,uvAC intra: 76.7% 73.1% 31.2% inter: 15.7% 9.2% 0.3%
# [libx264 @ 0x5641f4faa180] i16 v,h,dc,p: 29% 24%  9% 38%
# [libx264 @ 0x5641f4faa180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 13% 18%  7% 10% 10% 10%  8% 10%
# [libx264 @ 0x5641f4faa180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 16% 18%  7%  9%  9%  8%  6%  7%
# [libx264 @ 0x5641f4faa180] i8c dc,h,v,p: 67% 12% 17%  4%
# [libx264 @ 0x5641f4faa180] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5641f4faa180] ref P L0: 57.2% 18.9% 16.6%  7.3%
# [libx264 @ 0x5641f4faa180] ref B L0: 94.0%  4.4%  1.6%
# [libx264 @ 0x5641f4faa180] ref B L1: 98.1%  1.9%
# [libx264 @ 0x5641f4faa180] kb/s:6158.23
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55c0d7e1b5c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/0/28_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 6162 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 6158 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=  318 fps=8.4 q=-0.0 Lsize=N/A time=00:00:10.61 bitrate=N/A speed=0.279x
# video:147kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x55c0d8ceb780] VMAF score: 84.371796
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55c8c6c8c4c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c8c6c99180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55c8c6c99180] profile High, level 4.0
# [libx264 @ 0x55c8c6c99180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/0/17_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  318 fps= 11 q=-1.0 Lsize=   51658kB time=00:00:10.51 bitrate=40262.5kbits/s speed=0.373x    x
# video:51653kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.010308%
# [libx264 @ 0x55c8c6c99180] frame I:2     Avg QP:18.81  size:376082
# [libx264 @ 0x55c8c6c99180] frame P:79    Avg QP:20.47  size:293233
# [libx264 @ 0x55c8c6c99180] frame B:237   Avg QP:23.36  size:122254
# [libx264 @ 0x55c8c6c99180] consecutive B-frames:  0.6%  0.0%  0.0% 99.4%
# [libx264 @ 0x55c8c6c99180] mb I  I16..4:  0.0% 99.5%  0.4%
# [libx264 @ 0x55c8c6c99180] mb P  I16..4:  0.0% 41.7%  2.1%  P16..4: 12.6% 22.2% 21.3%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x55c8c6c99180] mb B  I16..4:  0.0%  6.5%  0.3%  B16..8: 27.2% 20.2%  9.2%  direct:22.6%  skip:14.0%  L0:25.2% L1:20.2% BI:54.6%
# [libx264 @ 0x55c8c6c99180] 8x8 transform intra:95.5% inter:77.1%
# [libx264 @ 0x55c8c6c99180] coded y,uvDC,uvAC intra: 98.6% 95.5% 68.8% inter: 71.3% 61.9% 12.5%
# [libx264 @ 0x55c8c6c99180] i16 v,h,dc,p:  7% 18%  9% 66%
# [libx264 @ 0x55c8c6c99180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 16% 19%  5%  8%  8%  9%  7% 10%
# [libx264 @ 0x55c8c6c99180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 15% 11%  8% 11% 10% 10%  9% 11%
# [libx264 @ 0x55c8c6c99180] i8c dc,h,v,p: 52% 18% 24%  7%
# [libx264 @ 0x55c8c6c99180] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55c8c6c99180] ref P L0: 39.8% 19.2% 28.8% 12.3%
# [libx264 @ 0x55c8c6c99180] ref B L0: 85.5% 11.3%  3.2%
# [libx264 @ 0x55c8c6c99180] ref B L1: 96.1%  3.9%
# [libx264 @ 0x55c8c6c99180] kb/s:39878.36
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x555f0a9d05c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/0/17_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 39881 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 39878 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=  318 fps=8.0 q=-0.0 Lsize=N/A time=00:00:10.61 bitrate=N/A speed=0.268x
# video:147kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x555f0b89fcc0] VMAF score: 98.609098
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x5588608744c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x558860881180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x558860881180] profile High, level 4.0
# [libx264 @ 0x558860881180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=24.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/0/24_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  318 fps= 18 q=-1.0 Lsize=   14624kB time=00:00:10.51 bitrate=11398.1kbits/s speed=0.607x    x
# video:14619kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.032625%
# [libx264 @ 0x558860881180] frame I:2     Avg QP:25.81  size:250262
# [libx264 @ 0x558860881180] frame P:79    Avg QP:27.43  size:110752
# [libx264 @ 0x558860881180] frame B:237   Avg QP:30.67  size: 24133
# [libx264 @ 0x558860881180] consecutive B-frames:  0.6%  0.0%  0.0% 99.4%
# [libx264 @ 0x558860881180] mb I  I16..4:  0.6% 94.2%  5.2%
# [libx264 @ 0x558860881180] mb P  I16..4:  0.1% 19.3%  1.7%  P16..4: 30.2% 22.7% 17.3%  0.0%  0.0%    skip: 8.8%
# [libx264 @ 0x558860881180] mb B  I16..4:  0.0%  1.0%  0.1%  B16..8: 34.1% 11.8%  3.5%  direct: 5.0%  skip:44.5%  L0:33.9% L1:39.7% BI:26.5%
# [libx264 @ 0x558860881180] 8x8 transform intra:91.6% inter:66.4%
# [libx264 @ 0x558860881180] coded y,uvDC,uvAC intra: 90.8% 85.3% 46.5% inter: 24.3% 17.2% 1.1%
# [libx264 @ 0x558860881180] i16 v,h,dc,p: 27% 25%  4% 44%
# [libx264 @ 0x558860881180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 15% 18%  6%  9% 10%  9%  8% 10%
# [libx264 @ 0x558860881180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 15% 15%  7% 11% 10%  9%  7%  8%
# [libx264 @ 0x558860881180] i8c dc,h,v,p: 59% 15% 20%  5%
# [libx264 @ 0x558860881180] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x558860881180] ref P L0: 47.1% 21.4% 23.8%  7.7%
# [libx264 @ 0x558860881180] ref B L0: 91.5%  6.7%  1.9%
# [libx264 @ 0x558860881180] ref B L1: 97.9%  2.1%
# [libx264 @ 0x558860881180] kb/s:11286.42
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x556d8ab505c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/0/24_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 11290 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 11286 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=  318 fps=8.1 q=-0.0 Lsize=N/A time=00:00:10.61 bitrate=N/A speed=0.272x
# video:147kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x556d8ba20340] VMAF score: 91.518566
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x563dee4404c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x563dee44d180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563dee44d180] profile High, level 4.0
# [libx264 @ 0x563dee44d180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=25.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/0/25_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  318 fps= 19 q=-1.0 Lsize=   12392kB time=00:00:10.51 bitrate=9658.0kbits/s speed=0.637x
# video:12387kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.038024%
# [libx264 @ 0x563dee44d180] frame I:2     Avg QP:26.81  size:228015
# [libx264 @ 0x563dee44d180] frame P:79    Avg QP:28.44  size: 92806
# [libx264 @ 0x563dee44d180] frame B:237   Avg QP:31.79  size: 20657
# [libx264 @ 0x563dee44d180] consecutive B-frames:  0.6%  0.0%  0.0% 99.4%
# [libx264 @ 0x563dee44d180] mb I  I16..4:  1.1% 91.3%  7.6%
# [libx264 @ 0x563dee44d180] mb P  I16..4:  0.2% 15.7%  1.6%  P16..4: 31.7% 22.4% 16.0%  0.0%  0.0%    skip:12.3%
# [libx264 @ 0x563dee44d180] mb B  I16..4:  0.0%  0.9%  0.1%  B16..8: 33.7% 10.8%  3.0%  direct: 4.3%  skip:47.2%  L0:34.4% L1:43.0% BI:22.6%
# [libx264 @ 0x563dee44d180] 8x8 transform intra:89.9% inter:67.1%
# [libx264 @ 0x563dee44d180] coded y,uvDC,uvAC intra: 87.8% 83.5% 43.5% inter: 21.8% 14.5% 0.8%
# [libx264 @ 0x563dee44d180] i16 v,h,dc,p: 27% 26%  4% 43%
# [libx264 @ 0x563dee44d180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 14% 17%  6% 10% 10%  9%  8% 10%
# [libx264 @ 0x563dee44d180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 16% 15%  7% 10% 10%  9%  7%  7%
# [libx264 @ 0x563dee44d180] i8c dc,h,v,p: 61% 14% 20%  5%
# [libx264 @ 0x563dee44d180] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563dee44d180] ref P L0: 50.5% 21.2% 20.8%  7.5%
# [libx264 @ 0x563dee44d180] ref B L0: 92.6%  5.7%  1.8%
# [libx264 @ 0x563dee44d180] ref B L1: 98.0%  2.0%
# [libx264 @ 0x563dee44d180] kb/s:9562.83
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x563d68bce5c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000000.yuv':
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/0/25_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:10.61, start: 0.000000, bitrate: 9566 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 9563 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=  318 fps=8.1 q=-0.0 Lsize=N/A time=00:00:10.61 bitrate=N/A speed=0.272x
# video:147kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x563d69a9e240] VMAF score: 90.026488
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55ea9dafb4c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000001.yuv':
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ea9db08180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ea9db08180] profile High, level 4.0
# [libx264 @ 0x55ea9db08180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=28.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/1/28_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# init computing -scene1
# frame=   60 fps= 21 q=-1.0 Lsize=    1887kB time=00:00:01.90 bitrate=8126.0kbits/s speed=0.655x
# video:1885kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.082265%
# [libx264 @ 0x55ea9db08180] frame I:1     Avg QP:32.75  size: 90084
# [libx264 @ 0x55ea9db08180] frame P:15    Avg QP:32.84  size: 64669
# [libx264 @ 0x55ea9db08180] frame B:44    Avg QP:35.72  size: 19762
# [libx264 @ 0x55ea9db08180] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x55ea9db08180] mb I  I16..4:  4.2% 83.2% 12.7%
# [libx264 @ 0x55ea9db08180] mb P  I16..4:  0.7% 22.2%  3.4%  P16..4: 38.8% 22.1%  7.5%  0.0%  0.0%    skip: 5.2%
# [libx264 @ 0x55ea9db08180] mb B  I16..4:  0.0%  0.9%  0.1%  B16..8: 46.8% 11.2%  2.1%  direct: 3.0%  skip:35.8%  L0:38.6% L1:49.4% BI:12.0%
# [libx264 @ 0x55ea9db08180] 8x8 transform intra:84.4% inter:80.2%
# [libx264 @ 0x55ea9db08180] coded y,uvDC,uvAC intra: 78.4% 70.8% 28.2% inter: 19.6% 10.8% 0.1%
# [libx264 @ 0x55ea9db08180] i16 v,h,dc,p: 23% 20%  6% 51%
# [libx264 @ 0x55ea9db08180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 13% 11%  7% 10% 12% 10% 10% 10%
# [libx264 @ 0x55ea9db08180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 15% 14%  8% 10% 10%  8%  8%  6%
# [libx264 @ 0x55ea9db08180] i8c dc,h,v,p: 60% 17% 17%  6%
# [libx264 @ 0x55ea9db08180] Weighted P-Frames: Y:6.7% UV:6.7%
# [libx264 @ 0x55ea9db08180] ref P L0: 70.4% 19.4%  8.5%  1.7%
# [libx264 @ 0x55ea9db08180] ref B L0: 97.6%  1.9%  0.5%
# [libx264 @ 0x55ea9db08180] ref B L1: 99.7%  0.3%
# [libx264 @ 0x55ea9db08180] kb/s:7710.89
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x56463f5ed5c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000001.yuv':
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/1/28_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 7716 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 7713 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=   60 fps=7.5 q=-0.0 Lsize=N/A time=00:00:02.00 bitrate=N/A speed=0.251x
# video:28kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x56463f622ac0] VMAF score: 95.537086
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x5627a28904c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000001.yuv':
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5627a289d180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5627a289d180] profile High, level 4.0
# [libx264 @ 0x5627a289d180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/1/17_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 11 q=-1.0 Lsize=    8843kB time=00:00:01.90 bitrate=38087.7kbits/s speed=0.357x
# video:8841kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.018689%
# [libx264 @ 0x5627a289d180] frame I:1     Avg QP:21.74  size:285761
# [libx264 @ 0x5627a289d180] frame P:15    Avg QP:21.67  size:269958
# [libx264 @ 0x5627a289d180] frame B:44    Avg QP:24.28  size:107222
# [libx264 @ 0x5627a289d180] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x5627a289d180] mb I  I16..4:  0.1% 98.1%  1.8%
# [libx264 @ 0x5627a289d180] mb P  I16..4:  0.0% 57.5%  3.7%  P16..4: 10.8% 17.2% 10.6%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x5627a289d180] mb B  I16..4:  0.0%  5.7%  0.6%  B16..8: 34.7% 23.7%  9.2%  direct:16.2%  skip: 9.8%  L0:26.5% L1:22.6% BI:51.0%
# [libx264 @ 0x5627a289d180] 8x8 transform intra:93.3% inter:62.1%
# [libx264 @ 0x5627a289d180] coded y,uvDC,uvAC intra: 98.0% 97.4% 76.7% inter: 61.8% 52.7% 6.7%
# [libx264 @ 0x5627a289d180] i16 v,h,dc,p: 17%  8%  3% 72%
# [libx264 @ 0x5627a289d180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 16% 11%  5%  9% 11% 10%  9% 11%
# [libx264 @ 0x5627a289d180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 13%  8%  7% 11% 12% 10% 10%  9%
# [libx264 @ 0x5627a289d180] i8c dc,h,v,p: 50% 19% 22%  9%
# [libx264 @ 0x5627a289d180] Weighted P-Frames: Y:6.7% UV:6.7%
# [libx264 @ 0x5627a289d180] ref P L0: 52.2% 25.1% 20.1%  2.6%
# [libx264 @ 0x5627a289d180] ref B L0: 93.9%  5.5%  0.6%
# [libx264 @ 0x5627a289d180] ref B L1: 99.5%  0.5%
# [libx264 @ 0x5627a289d180] kb/s:36175.35
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55c24be775c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000001.yuv':
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/1/17_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 36166 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 36178 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=   60 fps=7.6 q=-0.0 Lsize=N/A time=00:00:02.00 bitrate=N/A speed=0.253x
# video:28kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x55c24cd450c0] VMAF score: 99.920665
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x564f41c384c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000001.yuv':
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x564f41c45180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564f41c45180] profile High, level 4.0
# [libx264 @ 0x564f41c45180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=51.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/1/51_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps= 36 q=-1.0 Lsize=     170kB time=00:00:01.90 bitrate= 731.9kbits/s speed=1.15x
# video:168kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.911685%
# [libx264 @ 0x564f41c45180] frame I:1     Avg QP:51.00  size: 11580
# [libx264 @ 0x564f41c45180] frame P:15    Avg QP:51.00  size:  7154
# [libx264 @ 0x564f41c45180] frame B:44    Avg QP:51.00  size:  1201
# [libx264 @ 0x564f41c45180] consecutive B-frames:  1.7%  0.0%  5.0% 93.3%
# [libx264 @ 0x564f41c45180] mb I  I16..4: 48.9% 51.1%  0.0%
# [libx264 @ 0x564f41c45180] mb P  I16..4:  7.0%  2.7%  0.0%  P16..4: 29.7%  3.0%  2.3%  0.0%  0.0%    skip:55.3%
# [libx264 @ 0x564f41c45180] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 15.1%  0.0%  0.0%  direct: 0.0%  skip:84.9%  L0:37.2% L1:62.8% BI: 0.0%
# [libx264 @ 0x564f41c45180] 8x8 transform intra:37.4% inter:98.6%
# [libx264 @ 0x564f41c45180] coded y,uvDC,uvAC intra: 7.8% 31.9% 0.0% inter: 0.8% 1.5% 0.0%
# [libx264 @ 0x564f41c45180] i16 v,h,dc,p: 44% 33% 12% 11%
# [libx264 @ 0x564f41c45180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17%  9% 47%  6%  5%  5%  4%  4%  3%
# [libx264 @ 0x564f41c45180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25%  6% 44%  6%  0%  0%  0% 12%  6%
# [libx264 @ 0x564f41c45180] i8c dc,h,v,p: 98%  1%  1%  0%
# [libx264 @ 0x564f41c45180] Weighted P-Frames: Y:6.7% UV:6.7%
# [libx264 @ 0x564f41c45180] ref P L0: 75.2%  1.7% 17.3%  5.8%
# [libx264 @ 0x564f41c45180] ref B L0: 96.8%  2.3%  0.9%
# [libx264 @ 0x564f41c45180] ref B L1: 99.6%  0.4%
# [libx264 @ 0x564f41c45180] kb/s:686.27
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55aa8e0505c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000001.yuv':
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/1/51_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 694 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 689 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=   60 fps=8.3 q=-0.0 Lsize=N/A time=00:00:02.00 bitrate=N/A speed=0.278x
# video:28kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x55aa8ef1e640] VMAF score: 19.850423
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x563e574ec4c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000001.yuv':
# ...
# [libx264 @ 0x55c40bf7e180] ref B L0: 87.8%  9.9%  2.3%
# [libx264 @ 0x55c40bf7e180] ref B L1: 96.5%  3.5%
# [libx264 @ 0x55c40bf7e180] kb/s:27072.64
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55e1e59975c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000003.yuv':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/3/17_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 27070 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 27074 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=   90 fps=8.5 q=-0.0 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=0.284x
# video:41kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x55e1e6865c00] VMAF score: 99.930164
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55ab7d48b4c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000003.yuv':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ab7d498180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ab7d498180] profile High, level 4.0
# [libx264 @ 0x55ab7d498180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=26.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/3/26_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   90 fps= 22 q=-1.0 Lsize=    1846kB time=00:00:02.90 bitrate=5209.4kbits/s speed=0.709x
# video:1844kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.103527%
# [libx264 @ 0x55ab7d498180] frame I:1     Avg QP:28.88  size: 48397
# [libx264 @ 0x55ab7d498180] frame P:23    Avg QP:29.32  size: 34116
# [libx264 @ 0x55ab7d498180] frame B:66    Avg QP:30.71  size: 15980
# [libx264 @ 0x55ab7d498180] consecutive B-frames:  2.2%  0.0%  0.0% 97.8%
# [libx264 @ 0x55ab7d498180] mb I  I16..4: 17.8% 75.1%  7.1%
# [libx264 @ 0x55ab7d498180] mb P  I16..4:  5.2% 21.8%  1.4%  P16..4: 43.9%  9.5%  2.4%  0.0%  0.0%    skip:15.8%
# [libx264 @ 0x55ab7d498180] mb B  I16..4:  0.6%  2.8%  0.1%  B16..8: 48.5%  6.3%  0.7%  direct: 1.8%  skip:39.1%  L0:46.3% L1:50.6% BI: 3.1%
# [libx264 @ 0x55ab7d498180] 8x8 transform intra:77.4% inter:91.5%
# [libx264 @ 0x55ab7d498180] coded y,uvDC,uvAC intra: 48.0% 55.8% 15.6% inter: 15.8% 11.8% 0.1%
# [libx264 @ 0x55ab7d498180] i16 v,h,dc,p: 24% 13%  4% 58%
# [libx264 @ 0x55ab7d498180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 12% 14%  7% 11% 13% 10%  9%  7%
# [libx264 @ 0x55ab7d498180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 15% 14%  6% 12%  9%  8%  6%  3%
# [libx264 @ 0x55ab7d498180] i8c dc,h,v,p: 61% 15% 17%  6%
# [libx264 @ 0x55ab7d498180] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ab7d498180] ref P L0: 54.7% 17.2% 18.7%  9.5%
# [libx264 @ 0x55ab7d498180] ref B L0: 90.9%  6.7%  2.4%
# [libx264 @ 0x55ab7d498180] ref B L1: 97.2%  2.8%
# [libx264 @ 0x55ab7d498180] kb/s:5028.87
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55c7019d65c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000003.yuv':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/3/26_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5034 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 5030 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=   90 fps=8.2 q=-0.0 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=0.275x
# video:41kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x55c701a0e380] VMAF score: 91.769704
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x5631635804c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000003.yuv':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56316358d180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56316358d180] profile High, level 4.0
# [libx264 @ 0x56316358d180] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=27.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test_vids/temp_encoded/3/27_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 29.97 fps, 11988 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   90 fps= 22 q=-1.0 Lsize=    1654kB time=00:00:02.90 bitrate=4667.6kbits/s speed=0.713x
# video:1652kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.115559%
# [libx264 @ 0x56316358d180] frame I:1     Avg QP:29.88  size: 43968
# [libx264 @ 0x56316358d180] frame P:23    Avg QP:30.38  size: 30772
# [libx264 @ 0x56316358d180] frame B:66    Avg QP:31.79  size: 14233
# [libx264 @ 0x56316358d180] consecutive B-frames:  2.2%  0.0%  0.0% 97.8%
# [libx264 @ 0x56316358d180] mb I  I16..4: 19.5% 74.4%  6.0%
# [libx264 @ 0x56316358d180] mb P  I16..4:  5.7% 21.2%  1.1%  P16..4: 43.5%  8.3%  2.1%  0.0%  0.0%    skip:18.1%
# [libx264 @ 0x56316358d180] mb B  I16..4:  0.6%  2.5%  0.1%  B16..8: 47.7%  5.5%  0.6%  direct: 1.4%  skip:41.5%  L0:46.1% L1:51.2% BI: 2.7%
# [libx264 @ 0x56316358d180] 8x8 transform intra:76.2% inter:92.7%
# [libx264 @ 0x56316358d180] coded y,uvDC,uvAC intra: 43.9% 52.2% 13.1% inter: 13.7% 10.1% 0.1%
# [libx264 @ 0x56316358d180] i16 v,h,dc,p: 25% 15%  4% 55%
# [libx264 @ 0x56316358d180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 12% 15%  7% 11% 12% 10%  8%  7%
# [libx264 @ 0x56316358d180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 15% 14%  6% 12%  9%  8%  5%  3%
# [libx264 @ 0x56316358d180] i8c dc,h,v,p: 64% 14% 17%  6%
# [libx264 @ 0x56316358d180] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56316358d180] ref P L0: 54.9% 16.9% 18.8%  9.5%
# [libx264 @ 0x56316358d180] ref B L0: 90.8%  6.8%  2.4%
# [libx264 @ 0x56316358d180] ref B L1: 97.2%  2.8%
# [libx264 @ 0x56316358d180] kb/s:4505.07
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [rawvideo @ 0x55fd522805c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, rawvideo, from 'test_vids/tempRAW_refs/scene0000003.yuv':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 745749 kb/s
#   Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 1920x1080, 745749 kb/s, 29.97 tbr, 29.97 tbn
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'test_vids/temp_encoded/3/27_AVC.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.22.100
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 4510 kb/s
#   Stream #1:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 4506 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (rawvideo) -> setpts:default
#   Stream #1:0 (h264) -> scale:default
#   libvmaf:default -> Stream #0:0 (wrapped_avframe)
# Press [q] to stop, [?] for help
# Output #0, null, to 'pipe:':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0: Video: wrapped_avframe, yuv420p(progressive), 1920x1080, q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn
#     Metadata:
#       encoder         : Lavc59.26.100 wrapped_avframe
# frame=   90 fps=8.3 q=-0.0 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=0.276x
# video:41kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [Parsed_libvmaf_3 @ 0x55fd522b8300] VMAF score: 89.773034

# %% [markdown]
# ## Encode opt video
# Put together all the individually encoded shots

# %%
def mux(t_i, t_name, t_val):
    file_list = "" #list of encoded vids to be stored in OUT_LIST
    with open(rd_file, 'r') as f:
        o_data = json.load(f)
    for shot in range(0,num_scenes):
        opt_crf = o_data["versions"][0]["shots"][shot]["opt_points"][t_i]["crf"]
        file_list = file_list + "file '" + DIST_PATH + str(shot) + "/" \
        + str(opt_crf) + "_" + codec.upper() + "." + s_cod["container"] + "' \n"
    with open(OUT_LIST, 'w') as w:
        w.write(file_list)
    o = OUT_PATH+source_name[:9] + "_" + t_name + str(t_val) + "_" + codec.upper() + "." + s_cod["container"]
    mux = f"ffmpeg -f concat -i {OUT_LIST} -c copy {o}"
    subprocess.call(mux, shell=True)

# %%
target_index = 0
for t_name in target_list:
    for t_val in target_list[t_name]:
        mux(target_index, t_name, t_val)
        target_index += 1
# Out:
# ffmpeg version N-106635-g83e1a1de88 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/home/ubuntu/ffmpeg_build --pkg-config-flags=--static --extra-cflags=-I/home/ubuntu/ffmpeg_build/include --extra-ldflags=-L/home/ubuntu/ffmpeg_build/lib --extra-libs='-lpthread -lm' --ld=g++ --bindir=/home/ubuntu/bin --enable-gpl --enable-gnutls --enable-libaom --enable-libass --enable-libfdk-aac --enable-libfreetype --enable-libmp3lame --enable-libopus --enable-libsvtav1 --enable-libdav1d --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libvmaf --enable-version3 --enable-nonfree
#   libavutil      57. 24.101 / 57. 24.101
#   libavcodec     59. 26.100 / 59. 26.100
#   libavformat    59. 22.100 / 59. 22.100
#   libavdevice    59.  6.100 / 59.  6.100
#   libavfilter     8. 33.100 /  8. 33.100
#   libswscale      6.  6.100 /  6.  6.100
#   libswresample   4.  6.100 /  4.  6.100
#   libpostproc    56.  5.100 / 56.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5637876933c0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'shot_list.txt':
#   Duration: N/A, start: 0.000000, bitrate: 9563 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, 9563 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'test_vids/OPT_vids/rush_fiel_vmaf90_AVC.mp4':
#   Metadata:
#     encoder         : Lavf59.22.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=2-31, 9563 kb/s, 29.97 fps, 29.97 tbr, 11988 tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x563787694a00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5637876b3e00] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5637876a0100] Auto-inserting h264_mp4toannexb bitstream filter
# frame=  570 fps=0.0 q=-1.0 Lsize=   18150kB time=00:00:18.92 bitrate=7858.3kbits/s speed= 359x
# video:18142kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.043013%

# %% [markdown]
# ## TODO: Curve fitting
# When the upper search has tested 3 points, given these 3 RQ points, discover the polynomian or logarithmic function that describes their trend. Repeat this when a new point is computed. Measure the error between the approximation and the actual implementation (lagrangian search above) and assess whether and when it may be useful to speed up the search process, by reducing the number of test to encode before the optimum.
